# %% [markdown]
# <a href="https://colab.research.google.com/github/Gopal6988/phyton/blob/main/phyton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(type("hello world"))
# Out:
# <class 'str'>
